# %% [markdown]
# This file is a notebook from 29/06 onwards

# %%
# importing libraries
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn

import functions as fct

import importlib
importlib.reload(fct)

import ot               # optimal transport library

# %load_ext autoreload
# %autoreload 2
